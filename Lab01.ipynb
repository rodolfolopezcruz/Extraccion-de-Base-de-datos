# %%
import pandas as pd

# %%
datos = {
    "usuario" : ["Ana", "Luis", "Martha", "Carolina", "Sofia", "Pedro", "Elena", "Diego"],
    "Edad" : [25, 32, 28, 45, 37, 22, 31, 32],
    "ciudad" : ["CDMX", "Monterrey", "Guadalajara", "Puebla", "Cancun", "Merida", "Tijuana", "Toluca"],
    "compras_realizadas" : [5, 12, 21, 14, 34, 29,31, 15],
    "activo" : [True, False, True, False, True, False, True, False],
    "fecha_registro" : ["2025-09-16", "2025-02-14", "2023-05-10", "2026-05-01", "2023-10-02", "2023-01-06", "2025-12-24", "2025-12-31"],
    }

# %%
df = pd.DataFrame(datos)

# %%
print (df)
# Out:
#     usuario  Edad       ciudad  compras_realizadas  activo fecha_registro
# 0       Ana    25         CDMX                   5    True     2025-09-16
# 1      Luis    32    Monterrey                  12   False     2025-02-14
# 2    Martha    28  Guadalajara                  21    True     2023-05-10
# 3  Carolina    45       Puebla                  14   False     2026-05-01
# 4     Sofia    37       Cancun                  34    True     2023-10-02
# 5     Pedro    22       Merida                  29   False     2023-01-06
# 6     Elena    31      Tijuana                  31    True     2025-12-24
# 7     Diego    32       Toluca                  15   False     2025-12-31

# %%
df.head()
# Out:
#     usuario  Edad       ciudad  compras_realizadas  activo fecha_registro
# 0       Ana    25         CDMX                   5    True     2025-09-16
# 1      Luis    32    Monterrey                  12   False     2025-02-14
# 2    Martha    28  Guadalajara                  21    True     2023-05-10
# 3  Carolina    45       Puebla                  14   False     2026-05-01
# 4     Sofia    37       Cancun                  34    True     2023-10-02

# %%
cantidad = 1000000

# %%
import random

# %%
#datos aleatorios
nombres = ["Isabel", "Vanessa", "Maria", "Heidy", "Veronica", "Yosselin", "Zulema", "Ana"],
ciudades = ["CDMX", "Monterrey", "Guadalajara", "Puebla", "Cancun", "Merida", "Tijuana", "Toluca"],
categorias = ["Tecnologias", "Ropa", "Hogar", "Videojuegos", "Deportes", "Calzado", "Cosmeticos", "Infantil"]

# %%
#creacion del dataframe
dMilton = pd.DataFrame({
    "nombre" : [random.choice(nombres) for _ in range(cantidad)],
    "edad" : [random.randint(18,70) for _ in range(cantidad)],
    "salario" : [round(random.uniform(5000, 50000), 2) for _ in range (cantidad)],
    "activo" : [random.choice([True,False]) for _ in range(cantidad)],
    "categoria" : [random.choice(categorias) for _ in range(cantidad)], 
    "ciudad" : [random.choice(ciudades) for _ in range(cantidad)],
    "anio_registro" : [random.randint(2020,2026) for _ in range(cantidad)],
})

# %%
dMilton.dtypes
# Out:
# nombre            object
# edad               int64
# salario          float64
# activo              bool
# categoria            str
# ciudad            object
# anio_registro      int64
# dtype: object

# %%
dMilton.memory_usage(deep = True)
# Out:
# Index                  132
# nombre           128000000
# edad               8000000
# salario            8000000
# activo             1000000
# categoria         64998564
# ciudad           128000000
# anio_registro      8000000
# dtype: int64

# %%
dMilton.memory_usage(deep = True).sum() /1024*2
# Out:
# np.float64(675778.703125)
